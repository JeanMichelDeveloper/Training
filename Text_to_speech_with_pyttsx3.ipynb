# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanMichelDeveloper/Training/blob/main/Text_to_speech_with_pyttsx3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load available voices

# %%
#install pyttsx3
# !pip install pyttsx3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import necessary libraries
import pyttsx3 as tts
# !sudo apt update
# !sudo apt install espeak
# !sudo apt install ffmpeg
from IPython.display import Audio
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# ...

# %%
#initialize engine
engine = tts.init()

voices = engine.getProperty("voices")

#examine voices
for voice in voices:
  print(voice, "\n", voice.id)
# Out:
# <Voice id=afrikaans
#           name=afrikaans
#           languages=[b'\x05af']
#           gender=male
#           age=None>
#  afrikaans
# <Voice id=aragonese
#           name=aragonese
#           languages=[b'\x05an']
#           gender=male
#           age=None>
#  aragonese
# <Voice id=bulgarian
#           name=bulgarian
#           languages=[b'\x05bg']
#           gender=None
#           age=None>
#  bulgarian
# <Voice id=bosnian
#           name=bosnian
#           languages=[b'\x05bs']
#           gender=male
#           age=None>
#  bosnian
# <Voice id=catalan
#           name=catalan
#           languages=[b'\x05ca']
#           gender=male
#           age=None>
#  catalan
# <Voice id=czech
#           name=czech
#           languages=[b'\x05cs']
#           gender=male
#           age=None>
#  czech
# <Voice id=welsh
#           name=welsh
#           languages=[b'\x05cy']
#           gender=male
#           age=None>
#  welsh
# <Voice id=danish
# ...

# %%
#examine english voices
for voice in voices:
  if voice.name.startswith("en"):
    print(voice)
# Out:
# <Voice id=english
#           name=english
#           languages=[b'\x02en-gb']
#           gender=male
#           age=None>
# <Voice id=en-scottish
#           name=en-scottish
#           languages=[b'\x05en-sc']
#           gender=male
#           age=None>
# <Voice id=english-north
#           name=english-north
#           languages=[b'\x05en-uk-north']
#           gender=male
#           age=None>
# <Voice id=english_rp
#           name=english_rp
#           languages=[b'\x05en-uk-rp']
#           gender=male
#           age=None>
# <Voice id=english_wmids
#           name=english_wmids
#           languages=[b'\x05en-uk-wmids']
#           gender=male
#           age=None>
# <Voice id=english-us
#           name=english-us
#           languages=[b'\x02en-us']
#           gender=male
#           age=None>
# <Voice id=en-westindies
#           name=en-westindies
#           languages=[b'\x05en-wi']
#           gender=male
#           age=None>

# %%
engine.getProperty("rate")
# Out:
# 200

# %%
rate = 150
engine.setProperty("rate", rate)

# %% [markdown]
# Convert text to speech

# %%
#create text
text = "this is a text example to be read by TTS"

#transform to speech (audio file)
engine.save_to_file(text, "textToSpeechWithTTS.mp3")

engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d08b49512839> in <module>
#       5 engine.save_to_file(text, "textToSpeechWithTTS.mp3")
#       6
# ----> 7 engine.runAndWait()
#
# /usr/local/lib/python3.8/dist-packages/pyttsx3/engine.py in runAndWait(self)
#     178         self._inLoop = True
#     179         self._driverLoop = True
# --> 180         self.proxy.runAndWait()
#     181
#     182     def startLoop(self, useDriverLoop=True):
#
# /usr/local/lib/python3.8/dist-packages/pyttsx3/driver.py in runAndWait(self)
#     190         '''
#     191         self._push(self._engine.endLoop, tuple())
# --> 192         self._driver.startLoop()
#     193
#     194     def startLoop(self, useDriverLoop):
#
# /usr/local/lib/python3.8/dist-packages/pyttsx3/drivers/espeak.py in startLoop(self)
# ...

# %%
#Play audio
Audio("/content/textToSpeechWithTTS.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
